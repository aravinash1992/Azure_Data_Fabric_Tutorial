# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
print("Hello Avinash Bro!")
# Out:
# StatementMeta(, 45bba04d-7b51-42f2-94c7-ad57ab8a6ca7, 4, Finished, Available, Finished, False)
# Hello Avinash Bro!

# %% [markdown]
# %%html
# # **Data Engineering Session - 1**

# %%
df = spark.read.format("csv").option("header","true").load("Files/RawDataADLS/returns.csv")
# df now is a Spark DataFrame containing CSV data from "Files/RawDataADLS/returns.csv".
display(df)
# Out:
# StatementMeta(, 35d0c5d7-061f-46a1-a479-10eff7b96ba7, 3, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, b9952bc4-4c0c-4195-88a1-82f3645fd0b7)

# %%
df = spark.read.format("csv").option("header","true").load("abfss://avinashrajakprows@onelake.dfs.fabric.microsoft.com/avinashlakehouse.Lakehouse/Files/RawDataADLS")
# df now is a Spark DataFrame containing CSV data from "abfss://avinashrajakprows@onelake.dfs.fabric.microsoft.com/avinashlakehouse.Lakehouse/Files/RawDataADLS".
display(df)
# Out:
# StatementMeta(, 35d0c5d7-061f-46a1-a479-10eff7b96ba7, 5, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, da61dfcd-1666-4832-a284-cbc720ec6af0)

# %%
df = spark.sql("SELECT * FROM avinashlakehouse.adlstable LIMIT 1000")
display(df)
# Out:
# StatementMeta(, 35d0c5d7-061f-46a1-a479-10eff7b96ba7, 6, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, a14b3871-4a8d-49d5-b9d3-cfe09880445a)
